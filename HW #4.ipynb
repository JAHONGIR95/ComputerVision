# %%
#Transforming Image 1
import cv2
import numpy as np
from matplotlib import pyplot as plt
from pylab import *
img_1 = cv2.imread('photo.jpg')
pts1 = np.array([[324,280],[762,313],[325,535],[766,508]])
img_2 = cv2.imread('photo.jpg')
pts2 = np.array([[324,280],[762,340],[325,568],[760,508]])
h,status = cv2.findHomography(pts1,pts2)
new_img = cv2.warpPerspective(img_1,h,(img_2.shape[1],img_2.shape[0]))
fig, axs = subplots(1, 2, figsize=(16, 16))
axs[0].imshow(img_1)
axs[0].axis('off')
title('Transformed Image')
axs[1].imshow(new_img)
axs[1].axis('off')
plt.show()

# %%
#Transforming Image 2
import cv2
import numpy as np
from matplotlib import pyplot as plt
from pylab import *
img_1 = cv2.imread('photo3.jpg')
pts1 = np.array([[410,220],[780,300],[410,550],[860,530]])
img_2 = cv2.imread('photo3.jpg')
pts2 = np.array([[180,239],[822,150],[180,403],[819,513]])
h,status = cv2.findHomography(pts1,pts2)
new_img = cv2.warpPerspective(img_1,h,(img_2.shape[1],img_2.shape[0]))
fig, axs = subplots(1, 2, figsize=(16, 16))
axs[0].imshow(img_1)
axs[0].axis('off')
title('Transformed Image')
axs[1].imshow(new_img)
axs[1].axis('off')
plt.show()

# %%
#Transforming Image 3
import cv2
import numpy as np
from matplotlib import pyplot as plt
from pylab import *
img_1 = cv2.imread('photo4.jpg')
pts1 = np.array([[105,226],[701,161],[109,496],[703,539]])
img_2 = cv2.imread('photo4.jpg')
pts2 = np.array([[105,226],[701,226],[109,539],[703,539]])
h,status = cv2.findHomography(pts1,pts2)
new_img = cv2.warpPerspective(img_1,h,(img_2.shape[1],img_2.shape[0]))
fig, axs = subplots(1, 2, figsize=(16, 16))
axs[0].imshow(img_1)
axs[0].axis('off')
title('Transformed Image')
axs[1].imshow(new_img)
axs[1].axis('off')
plt.show()
